# %% [markdown]
# # **[Decentralizing Feature Extraction with Quantum Convolutional Neural Network for Automatic Speech Recognition](https://arxiv.org/abs/2010.13309)**  IEEE ICASSP 2021, June
#
# Author: C.-H. Huck Yang*
#
# Code Successuflly Complied in April 2021.
# Noted this may be changed by colab's backend.
#
# Georgia Tech*, Brookhaven National Laboratory, IBM Research, University of Enna
#
# We would like to appreciate Xanadu AI for providing the PennyLane and IBM research for providing qiskit and quantum hardware to the community. There is no conflict of interest. We got the inspiration from the [post](https://pennylane.ai/qml/demos/tutorial_quanvolution.html) as Xanadu's demo (Author: Andrea Mari) and further apply some neural saliency analysis. [Colab Link](https://colab.research.google.com/drive/11Yi53W6-Z-uW84A8Sr6OqOMlBIel1PKM?usp=sharing)

# %%
# !git clone https://github.com/huckiyang/QuantumSpeech-QCNN
# %cd QuantumSpeech-QCNN
# Out:
# Cloning into 'QuantumSpeech-QCNN'...
# remote: Enumerating objects: 580, done.
# remote: Counting objects: 100% (222/222), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 580 (delta 132), reused 222 (delta 132), pack-reused 358
# Receiving objects: 100% (580/580), 879.45 MiB | 1.77 MiB/s, done.
# Resolving deltas: 100% (330/330), done.
# Updating files: 100% (41/41), done.
# /Users/niticon/comp-ling/thesis/QuantumSpeech-QCNN

# %% [markdown]
# # **Command Classification Training with CE Loss**

# %%
# !pip install pennylane
# !pip install qiskit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 3.4 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.8/48.8 kB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 2.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.3/231.3 kB 2.4 MB/s eta 0:00:002.9 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.2/829.2 kB 6.4 MB/s eta 0:00:00m eta 0:00:010:00:01
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491058 sha256=f5c146330f063fbfcd19ef76393f5dae62e03e32276e1471fec9f9640ea10b8c
#   Stored in directory: /Users/niticon/Library/Caches/pip/wheels/8e/70/28/3d6ccd6e315f65f245da085482a2e1c7d14b90b30f239e2cf4
# Successfully built future
# ...
# Traceback (most recent call last):
#   File "main_qsr.py", line 2, in <module>
#     import librosa
# ImportError: No module named librosa

# %%
# !pip install librosa
# !python main_qsr.py
# Out:
# ...
# Traceback (most recent call last):
#   File "main_qsr.py", line 2, in <module>
#     import librosa
# ImportError: No module named librosa

# %% [markdown]
# # **Neural Saliency by Class Activation Mapping (CAM)**

# %%
# !python cam_sp.py
# Out:
# Traceback (most recent call last):
#   File "cam_sp.py", line 1, in <module>
#     from tensorflow import keras
# ImportError: No module named tensorflow

# %%
from IPython.display import Image
Image('images/cam_sp_0.png')

# %% [markdown]
# # **Part 2. CTC model with Word Error Rate(WER) evaluation**

# %%
# %cd data_quantum/asr_set
# !bash unzip.sh
# %cd ../..

# %%
# !python qsr_ctc_wer.py
